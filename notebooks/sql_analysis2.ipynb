# %%
import sys
import pandas as pd
import sqlite3

print(sys.executable)
print(pd.__version__)
print(sqlite3.sqlite_version)
# Out:
# c:\Users\Nestor\AppData\Local\Programs\Python\Python313\python.exe
# 2.3.0
# 3.45.3

# %%
import pandas as pd
import sqlite3

# %%
df = pd.read_csv("../data/spotify_clean.csv")
conn = sqlite3.connect("../data/spotify.db")
df.to_sql('tracks', conn, if_exists='replace', index=False)
|
# Out:
#   Cell In[3], line 4
#     |
#     ^
# SyntaxError: invalid syntax

# %%
df = pd.read_csv("../data/spotify_clean.csv")
conn = sqlite3.connect("../data/spotify.db")
df.to_sql('tracks', conn, if_exists='replace', index=False)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df = pd.read_csv("../data/spotify_clean.csv")
#       2 conn = sqlite3.connect("../data/spotify.db")
#       3 df.to_sql('tracks', conn, if_exists='replace', index=False)
#
# File c:\Users\Nestor\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)   1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\Nestor\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File c:\Users\Nestor\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\Nestor\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File c:\Users\Nestor\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../data/spotify_clean.csv'

# %%
pd.read_sql("""
    SELECT track_genre,
           ROUND(AVG(popularity), 1) AS avg_popularity,
           COUNT(*) AS track_count
    FROM tracks
    GROUP BY track_genre
    ORDER BY avg_popularity DESC
    LIMIT 10
""", conn)
# Out:
#   track_genre  avg_popularity  track_count
# 0    pop-film            59.3          998
# 1       k-pop            57.0          997
# 2       chill            53.8          998
# 3         sad            52.4         1000
# 4      grunge            49.6          998
# 5      indian            49.5          998
# 6       anime            48.8          998
# 7         pop            48.2          986
# 8         emo            48.1         1000
# 9   sertanejo            47.9         1000

# %%
pd.read_sql("""
    SELECT explicit,
           ROUND(AVG(popularity), 1) AS avg_popularity,
           COUNT(*) AS track_count
    FROM tracks
    GROUP BY explicit
""", conn)
# Out:
#    explicit  avg_popularity  track_count
# 0         0            33.1       103416
# 1         1            36.6         9689

# %%
pd.read_sql("""
    SELECT key, mode,
           ROUND(AVG(popularity), 1) AS avg_popularity,
           COUNT(*) AS track_count
    FROM tracks
    GROUP BY key, mode
    ORDER BY avg_popularity DESC
    LIMIT 10
""", conn)
# Out:
#    key  mode  avg_popularity  track_count
# 0    4     1            36.2         4257
# 1    1     0            35.0         3577
# 2    2     0            34.8         2553
# 3    6     0            34.7         3787
# 4    0     0            34.6         2834
# 5    2     1            34.5         8994
# 6    8     0            34.5         1906
# 7   11     1            34.4         4112
# 8    3     1            34.1         2202
# 9    5     0            34.0         3990

# %%
pd.read_sql("""
    SELECT track_name, artists, track_genre, popularity
    FROM tracks
    ORDER BY popularity DESC
    LIMIT 10
""", conn)
# Out:
#                               track_name                  artists track_genre  \
# 0              Unholy (feat. Kim Petras)     Sam Smith;Kim Petras       dance
# 1              Unholy (feat. Kim Petras)     Sam Smith;Kim Petras         pop
# 2  Quevedo: Bzrp Music Sessions, Vol. 52         Bizarrap;Quevedo     hip-hop
# 3                        I'm Good (Blue)  David Guetta;Bebe Rexha       dance
# 4                        I'm Good (Blue)  David Guetta;Bebe Rexha         edm
# 5                             La Bachata            Manuel Turizo       latin
# 6                             La Bachata            Manuel Turizo      latino
# 7                        I'm Good (Blue)  David Guetta;Bebe Rexha         pop
# 8                             La Bachata            Manuel Turizo      reggae
# 9                             La Bachata            Manuel Turizo   reggaeton
#
#    popularity
# 0         100
# 1         100
# 2          99
# 3          98
# 4          98
# 5          98
# 6          98
# 7          98
# 8          98
# 9          98

# %%
pd.read_sql("""
    SELECT DISTINCT(track_name), artists, track_genre, popularity
    FROM tracks
    ORDER BY popularity DESC
    LIMIT 10
""", conn)
# Out:
#                               track_name                  artists track_genre  \
# 0              Unholy (feat. Kim Petras)     Sam Smith;Kim Petras       dance
# 1              Unholy (feat. Kim Petras)     Sam Smith;Kim Petras         pop
# 2  Quevedo: Bzrp Music Sessions, Vol. 52         Bizarrap;Quevedo     hip-hop
# 3                        I'm Good (Blue)  David Guetta;Bebe Rexha       dance
# 4                        I'm Good (Blue)  David Guetta;Bebe Rexha         edm
# 5                             La Bachata            Manuel Turizo       latin
# 6                             La Bachata            Manuel Turizo      latino
# 7                        I'm Good (Blue)  David Guetta;Bebe Rexha         pop
# 8                             La Bachata            Manuel Turizo      reggae
# 9                             La Bachata            Manuel Turizo   reggaeton
#
#    popularity
# 0         100
# 1         100
# 2          99
# 3          98
# 4          98
# 5          98
# 6          98
# 7          98
# 8          98
# 9          98

# %%
pd.read_sql("""
    SELECT track_name, artists, track_genre, popularity
    FROM tracks
    GROUP BY track_name
    ORDER BY popularity DESC
    LIMIT 10
""", conn)
# Out:
#                               track_name                     artists  \
# 0              Unholy (feat. Kim Petras)        Sam Smith;Kim Petras
# 1  Quevedo: Bzrp Music Sessions, Vol. 52            Bizarrap;Quevedo
# 2                             La Bachata               Manuel Turizo
# 3                        I'm Good (Blue)     David Guetta;Bebe Rexha
# 4                       Tití Me Preguntó                   Bad Bunny
# 5                        Me Porto Bonito  Bad Bunny;Chencho Corleone
# 6                        I Ain't Worried                 OneRepublic
# 7                                 Efecto                   Bad Bunny
# 8                          Ojitos Lindos     Bad Bunny;Bomba Estéreo
# 9                            Moscow Mule                   Bad Bunny
#
#   track_genre  popularity
# 0       dance         100
# 1     hip-hop          99
# 2       latin          98
# 3       dance          98
# 4       latin          97
# 5       latin          97
# 6       piano          96
# 7       latin          96
# 8       latin          95
# 9       latin          94

# %%
pd.read_sql("""
    SELECT AVG(popularity) as avg_popularity
    FROM tracks
    WHERE track_genre = 'rock'
""", conn)
# Out:
#    avg_popularity
# 0          19.001

# %%
pd.read_sql("""
    SELECT AVG(popularity) as avg_popularity
    FROM tracks
""", conn)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 4
#       1 pd.read_sql("""
#       2     SELECT AVG(popularity) as avg_popularity
#       3     FROM tracks
# ----> 4 """, conn)
#
# NameError: name 'conn' is not defined
